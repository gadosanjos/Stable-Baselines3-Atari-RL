# %%
import torch

print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version used by PyTorch:", torch.version.cuda)

if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
else:
    print("No CUDA GPU detected by this Python environment.")
# Out:
# PyTorch version: 2.11.0+cu128
# CUDA available: True
# CUDA version used by PyTorch: 12.8
# GPU name: NVIDIA GeForce RTX 3060 Laptop GPU

# %%
import torch
from stable_baselines3 import DQN

print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
# Out:
# Torch: 2.11.0+cu128
# CUDA available: True
# GPU: NVIDIA GeForce RTX 3060 Laptop GPU

# %%
import gymnasium as gym
import ale_py

gym.register_envs(ale_py)

print("Gymnasium:", gym.__version__)
print("ALE registered successfully")

import torch
from stable_baselines3 import DQN
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack

print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0))

env = make_atari_env("ALE/Pong-v5", n_envs=1, seed=0)
env = VecFrameStack(env, n_stack=4)

model = DQN(
    "CnnPolicy",
    env,
    verbose=1,
    learning_rate=1e-4,
    buffer_size=10_000,
    learning_starts=1_000,
    batch_size=32,
    gamma=0.99,
    train_freq=4,
    target_update_interval=1000,
    device="cuda",
)

print("SB3 model device:", model.device)

model.learn(total_timesteps=5_000)

model.save("dqn_pong_smoke_test_cuda")

env.close()

print("Tiny DQN CUDA smoke test complete.")
# Out:
# Gymnasium: 1.2.3
# ALE registered successfully
# Torch: 2.11.0+cu128
# CUDA available: True
# GPU: NVIDIA GeForce RTX 3060 Laptop GPU
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# SB3 model device: cuda
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 851      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 639      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 831      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 833      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 402      |
# |    time_elapsed     | 4        |
# ...
